# %% [markdown]
# # Dataset Preview
#
# This notebook previews the tiny customer support instruction dataset used by the LoRA fine-tuning demo.

# %%
import json
from pathlib import Path

path = Path('../data/raw/sample_support_dataset.jsonl')
rows = [json.loads(line) for line in path.read_text(encoding='utf-8').splitlines() if line.strip()]
len(rows), rows[0]

# %%
import pandas as pd
pd.DataFrame(rows).head()
